# %% [markdown]
# # Building a plotly choropleth map with slider
# The goal is to combine plotly's choropleth map (https://plot.ly/python/choropleth-maps/) with the slider example (https://plot.ly/python/gapminder-example/).
#
# First I searched plotly's community forum and the web for an example of a plotly choropleth map with grid data or a slider without success.
#
# While I managed to replicate the slider animation example with my data (https://plot.ly/~mathias.riechert/59), adapting the choropleth code to access grid data with a slider does not seem to work.
#
# In contrast to a regular map (like in example one), data is not loaded from a dataframe column but is uploaded to a plotly grid. In example two we can see that instead of regular x,y and text values in the data_dict, xsrc, ysrc and textsrc are used to access the grid data.
#
#     data_dict = {
#            'xsrc': grid.get_column_reference(col_name_template.format(
#                 year=year, continent=continent, header='lifeExp'
#             )),
#             'ysrc': grid.get_column_reference(col_name_template.format(
#                 year=year, continent=continent, header='gdpPercap'
#             )),
#
#
# Chloropleth maps are defined in plotly by setting locations, z-values and text values in list form. In order to check if plotly choropleth maps support grid data, I searched in the api-documentation (https://plot.ly/python/reference/#choropleth) and found equivalents: locationsrc, zsrc, and textsrc. Therefore using grid data should be possible. When I draw my adapted graph though, I see only the coastline and the slider but no countries being highlighted.

# %% [markdown]
# ## Load data

# %%
import pandas as pd
import plotly   
import plotly.plotly as py
import time
from plotly.grid_objs import Grid, Column
plotly.__version__
# Out:
# '1.13.0'

# %%
dataset_original=pd.read_csv("data_paper_country.csv",sep=";")

dataset_original=dataset_original.drop(dataset_original.columns[[0]], axis=1)

dataset_original
# Out:
#                                DOI  PUBYEAR  AUTHOR_CNT  REF_CNT  COUNTRY_CNT  \
# 0                  10.1002/ad.1700     2014         1.0      6.0          1.0
# 1                  10.1002/ad.1700     2014         1.0      6.0          1.0
# 2        10.3305/nh.2014.29.4.7275     2014         4.0     72.0          1.0
# 3        10.3305/nh.2014.29.4.7275     2014         4.0     72.0          1.0
# 4        10.3305/nh.2014.29.4.7275     2014         4.0     72.0          1.0
# 5        10.3305/nh.2014.29.4.7275     2014         4.0     72.0          1.0
# 6        10.3305/nh.2014.29.4.7275     2014         4.0     72.0          1.0
# 7        10.3305/nh.2014.29.4.7275     2014         4.0     72.0          1.0
# 8     10.1016/j.amepre.2011.01.006     2011         3.0     63.0          1.0
# 9     10.1016/j.amepre.2011.01.006     2011         3.0     63.0          1.0
# 10    10.1080/03632415.2014.946128     2014         2.0     50.0          1.0
# 11    10.1080/03632415.2014.946128     2014         2.0     50.0          1.0
# 12    10.1080/03632415.2014.946128     2014         2.0     50.0          1.0
# 13    10.1016/j.amepre.2011.01.006     2011         3.0     63.0          1.0
# 14    10.1016/j.amepre.2011.01.006     2011         3.0     63.0          1.0
# 15        10.1186/1471-2105-14-191     2013         2.0     38.0          1.0
# 16        10.1186/1471-2105-14-191     2013         2.0     38.0          1.0
# 17        10.1186/1471-2105-14-191     2013         2.0     38.0          1.0
# 18        10.1186/1471-2105-14-191     2013         2.0     38.0          1.0
# 19        10.1186/1471-2105-14-191     2013         2.0     38.0          1.0
# 20                             NaN     2014        10.0     15.0          4.0
# 21                             NaN     2014        10.0     15.0          4.0
# 22                             NaN     2014        10.0     15.0          4.0
# 23                             NaN     2014        10.0     15.0          4.0
# 24                             NaN     2014        10.0     15.0          4.0
# 25                             NaN     2014        10.0     15.0          4.0
# 26                             NaN     2014        10.0     15.0          4.0
# 27                             NaN     2014        10.0     15.0          4.0
# 28                             NaN     2014        10.0     15.0          4.0
# 29                             NaN     2014        10.0     15.0          4.0
# ...                            ...      ...         ...      ...          ...
# 3139     10.1007/s10916-015-0220-8     2015         6.0     40.0          1.0
# 3140     10.1007/s10916-015-0220-8     2015         6.0     40.0          1.0
# 3141     10.1007/s10916-015-0220-8     2015         6.0     40.0          1.0
# 3142     10.1007/s10916-015-0220-8     2015         6.0     40.0          1.0
# 3143     10.1007/s10916-015-0220-8     2015         6.0     40.0          1.0
# 3144     10.1007/s10916-015-0220-8     2015         6.0     40.0          1.0
# 3145     10.1007/s11277-014-1689-z     2014         2.0     34.0          1.0
# 3146     10.1007/s11277-014-1689-z     2014         2.0     34.0          1.0
# 3147     10.1007/s11277-014-1689-z     2014         2.0     34.0          1.0
# 3148     10.1007/s11434-014-0645-3     2014         4.0     48.0          1.0
# 3149     10.1007/s11434-014-0645-3     2014         4.0     48.0          1.0
# 3150     10.1007/s11434-014-0645-3     2014         4.0     48.0          1.0
# 3151     10.1007/s11434-014-0645-3     2014         4.0     48.0          1.0
# 3152     10.1007/s11434-014-0645-3     2014         4.0     48.0          1.0
# 3153                           NaN     2014         1.0     62.0          1.0
# 3154                           NaN     2014         1.0     62.0          1.0
# 3155      10.4018/ijdwm.2014100103     2014         2.0     43.0          1.0
# 3156      10.4018/ijdwm.2014100103     2014         2.0     43.0          1.0
# 3157      10.4018/ijdwm.2014100103     2014         2.0     43.0          1.0
# 3158              10.1002/dac.2734     2014         3.0     49.0          1.0
# 3159              10.1002/dac.2734     2014         3.0     49.0          1.0
# 3160              10.1002/dac.2734     2014         3.0     49.0          1.0
# 3161              10.1002/dac.2734     2014         3.0     49.0          1.0
# 3162     10.1016/j.jss.2014.07.024     2015         5.0     42.0          1.0
# 3163     10.1016/j.jss.2014.07.024     2015         5.0     42.0          1.0
# 3164     10.1016/j.jss.2014.07.024     2015         5.0     42.0          1.0
# 3165     10.1016/j.jss.2014.07.024     2015         5.0     42.0          1.0
# 3166     10.1016/j.jss.2014.07.024     2015         5.0     42.0          1.0
# 3167     10.1016/j.jss.2014.07.024     2015         5.0     42.0          1.0
# 3168     10.1016/j.jss.2014.07.024     2015         5.0     42.0          1.0
#
#       INST_CNT  CIT_CNT COUNTRYCODE                  keyword
# 0          1.0      0.0         GBR                 big data
# 1          1.0      0.0         GBR                 big data
# 2          2.0      1.0         ESP                 big data
# 3          2.0      1.0         ESP                 big data
# 4          2.0      1.0         ESP                 big data
# 5          2.0      1.0         ESP                 big data
# 6          2.0      1.0         ESP                 big data
# 7          2.0      1.0         ESP                 big data
# 8          1.0      4.0         USA                 big data
# 9          1.0      4.0         USA                 big data
# 10         2.0      0.0         USA                 big data
# 11         2.0      0.0         USA                 big data
# 12         2.0      0.0         USA                 big data
# 13         1.0      4.0         USA                 big data
# 14         1.0      4.0         USA                 big data
# 15         2.0      4.0         AUT                 big data
# 16         2.0      4.0         AUT                 big data
# 17         2.0      4.0         AUT                 big data
# 18         2.0      4.0         AUT                 big data
# 19         2.0      4.0         AUT                 big data
# 20        10.0      0.0         CHN                 big data
# 21        10.0      0.0         CHN                 big data
# 22        10.0      0.0         JPN                 big data
# 23        10.0      0.0         JPN                 big data
# 24        10.0      0.0         CHN                 big data
# 25        10.0      0.0         JPN                 big data
# 26        10.0      0.0         JPN                 big data
# 27        10.0      0.0         JPN                 big data
# 28        10.0      0.0         CHN                 big data
# 29        10.0      0.0         CAN                 big data
# ...        ...      ...         ...                      ...
# 3139       2.0      0.0         CHN         medical big data
# 3140       2.0      0.0         CHN         medical big data
# 3141       2.0      0.0         CHN         medical big data
# 3142       2.0      0.0         CHN         medical big data
# 3143       2.0      0.0         CHN         medical big data
# 3144       2.0      0.0         CHN         medical big data
# 3145       2.0      0.0         DNK        mega and big data
# 3146       2.0      0.0         DNK        mega and big data
# 3147       2.0      0.0         DNK        mega and big data
# 3148       1.0      0.0         CHN      scientific big data
# 3149       1.0      0.0         CHN      scientific big data
# 3150       1.0      0.0         CHN      scientific big data
# 3151       1.0      0.0         CHN      scientific big data
# 3152       1.0      0.0         CHN      scientific big data
# 3153       1.0      0.0         USA         spatial big data
# 3154       1.0      0.0         USA         spatial big data
# 3155       1.0      0.0         CHN  spatial big data mining
# 3156       1.0      0.0         CHN  spatial big data mining
# 3157       1.0      0.0         CHN  spatial big data mining
# 3158       2.0      1.0         KOR          stream big data
# 3159       2.0      1.0         KOR          stream big data
# 3160       2.0      1.0         KOR          stream big data
# 3161       2.0      1.0         KOR          stream big data
# 3162       2.0      0.0         CHN    surveillance big data
# 3163       2.0      0.0         CHN    surveillance big data
# 3164       2.0      0.0         CHN    surveillance big data
# 3165       2.0      0.0         CHN    surveillance big data
# 3166       2.0      0.0         CHN    surveillance big data
# 3167       2.0      0.0         CHN    surveillance big data
# 3168       2.0      0.0         CHN    surveillance big data
#
# [3169 rows x 9 columns]

# %% [markdown]
# ## Group data by pubyear and countrycode

# %%
#group by year and country:
grouped=dataset_original.groupby(['PUBYEAR','COUNTRYCODE'])

# %%
#aggregate to mean, count rows per group:
dataset=grouped.agg('mean')\
             .rename(columns = lambda x: x + ' mean')\
             .join(pd.DataFrame(grouped.size(), 
                                columns=['NUM_PAPERS'])).reset_index()
dataset
# Out:
#      PUBYEAR COUNTRYCODE  Unnamed: 0 mean  AUTHOR_CNT mean  REF_CNT mean  \
# 0       2009         GBR       322.600000         4.000000     17.000000
# 1       2010         CAN       114.500000         1.000000     41.000000
# 2       2010         USA        38.500000         8.000000     54.000000
# 3       2011         CHE       344.000000         2.000000    151.000000
# 4       2011         USA       660.562500         2.687500     37.000000
# 5       2012         AUS      1217.000000         5.000000     53.000000
# 6       2012         CAN      2682.500000        17.000000      1.000000
# 7       2012         CHN       590.238095         6.285714     26.142857
# 8       2012         DEU       649.500000         1.000000      4.000000
# 9       2012         FRA      2028.500000         5.000000     35.000000
# 10      2012         GBR      2054.111111         1.333333     34.555556
# 11      2012         SAU      1468.000000         5.000000     44.000000
# 12      2012         USA      1277.111111         3.694444     40.250000
# 13      2013         AUS      1956.380952         5.666667     65.714286
# 14      2013         AUT        17.000000         2.000000     38.000000
# 15      2013         BEL      1078.000000        11.000000     11.000000
# 16      2013         CAN      1126.117647        11.176471     73.588235
# 17      2013         CHE       959.933333        12.866667     48.000000
# 18      2013         CHN       890.887097         6.903226     36.967742
# 19      2013         DEU       157.571429         3.142857     28.571429
# 20      2013         ECU       821.000000         6.000000     29.000000
# 21      2013         ESP      1465.000000         3.555556     23.333333
# 22      2013         GBR      1914.629630         6.500000     50.925926
# 23      2013         IRL      1353.500000         3.000000     68.000000
# 24      2013         ISR      2630.666667         2.000000     36.000000
# 25      2013         ITA      1594.714286         4.714286     10.142857
# 26      2013         JPN       515.052632         9.105263    111.842105
# 27      2013         KOR      1306.000000         2.444444     50.333333
# 28      2013         NLD      1310.187500         6.687500     71.875000
# 29      2013         NOR       375.500000        22.000000    110.000000
# ..       ...         ...              ...              ...           ...
# 77      2014         SGP       820.714286         3.523810     44.904762
# 78      2014         SWE       635.727273         3.000000     42.181818
# 79      2014         TWN      1099.300000         3.200000     45.533333
# 80      2014         USA      1312.849406         6.126816     51.568032
# 81      2015         AUS      1240.592593         8.148148     56.518519
# 82      2015         AUT         1.500000         3.000000     29.000000
# 83      2015         BEL      2486.000000        38.000000    122.000000
# 84      2015         CAN       635.583333         5.416667     48.000000
# 85      2015         CHN      1008.323171         5.219512     48.219512
# 86      2015         DEU      1652.804878        21.292683     76.097561
# 87      2015         DNK      2478.000000        38.000000    122.000000
# 88      2015         ESP      1185.434783         4.217391     40.826087
# 89      2015         FRA      1746.000000        20.000000     87.000000
# 90      2015         GBR      1022.675000         5.600000     52.250000
# 91      2015         IRL      1835.000000        27.000000     88.333333
# 92      2015         ISR      1105.714286         2.571429     28.428571
# 93      2015         ITA       584.636364         4.212121     44.939394
# 94      2015         JPN       843.400000         9.800000     43.000000
# 95      2015         KOR       397.961538         2.461538     29.500000
# 96      2015         MEX      2501.000000        38.000000    122.000000
# 97      2015         MYS      1516.300000         4.800000     99.600000
# 98      2015         NLD      2489.500000        38.000000    122.000000
# 99      2015         NOR      1510.000000         2.000000     25.000000
# 100     2015         PAK       202.000000         4.000000     47.000000
# 101     2015         POL      1777.000000         7.000000     35.000000
# 102     2015         SWE      1681.200000         1.600000     30.800000
# 103     2015         TWN       840.000000         5.000000     26.000000
# 104     2015         URY       530.000000         5.000000    161.000000
# 105     2015         USA      1657.185185         7.767677     38.757576
# 106     2015         ZAF      2492.000000        38.000000    122.000000
#
#      COUNTRY_CNT mean  INST_CNT mean  CIT_CNT mean  NUM_PAPERS
# 0            1.000000       1.000000     12.000000           5
# 1            1.000000       1.000000      7.000000           2
# 2            1.000000       7.000000      6.000000          10
# 3            2.000000       2.000000     16.000000           3
# 4            1.062500       1.687500      3.375000          16
# 5            2.000000       3.000000     23.000000           3
# 6            2.000000       2.000000      1.000000           2
# 7            1.714286       2.857143      8.142857          21
# 8            1.000000       1.000000      0.000000           2
# 9            2.000000       2.000000      7.000000           2
# 10           1.000000       1.000000      4.555556           9
# 11           2.000000       4.000000     15.000000           1
# 12           1.277778       2.166667     17.333333          36
# 13           2.428571       3.809524      2.190476          21
# 14           1.000000       2.000000      4.000000           5
# 15           5.000000       9.000000      7.000000           1
# 16           5.117647       9.117647      2.235294          17
# 17           5.866667      10.733333      5.200000          15
# 18           1.225806       1.967742      1.129032          62
# 19           1.000000       1.714286      0.000000           7
# 20           2.000000       3.000000      0.000000           1
# 21           1.000000       1.444444      0.000000           9
# 22           2.537037       5.074074      5.129630          54
# 23           1.000000       1.000000     11.000000           4
# 24           1.000000       1.000000      1.000000           3
# 25           2.428571       3.571429      2.714286           7
# 26           1.000000       4.052632      3.052632          19
# 27           1.222222       1.222222      4.777778           9
# 28           2.750000       5.437500      1.375000          16
# 29           9.500000      18.500000      2.500000           8
# ..                ...            ...           ...         ...
# 77           2.047619       2.095238      0.571429          21
# 78           1.272727       1.636364      0.363636          11
# 79           1.300000       2.033333      0.566667          30
# 80           1.482166       3.680317      1.043593         757
# 81           2.814815       4.481481      0.000000          27
# 82           1.000000       2.000000      0.000000           4
# 83          14.000000      22.000000      0.000000           1
# 84           2.250000       3.000000      0.000000          12
# 85           1.384146       2.847561      0.219512         164
# 86           7.073171      10.829268      0.000000          41
# 87          14.000000      22.000000      0.000000           7
# 88           1.217391       1.434783      0.434783          23
# 89           8.500000      12.500000      0.500000           2
# 90           2.100000       3.375000      0.975000          40
# 91          10.000000      15.333333      0.000000           3
# 92           1.000000       1.000000      0.000000           7
# 93           1.121212       1.636364      0.000000          33
# 94           3.800000       5.400000      0.000000           5
# 95           1.153846       2.115385      0.076923          26
# 96          14.000000      22.000000      0.000000           1
# 97           1.600000       1.600000      0.400000          10
# 98          14.000000      22.000000      0.000000           2
# 99           1.000000       1.000000      0.000000           3
# 100          2.000000       2.000000      0.000000           1
# 101          3.000000       6.000000      0.000000           1
# 102          1.000000       1.000000      0.000000           5
# 103          2.000000       2.000000      0.000000           3
# 104          1.000000       2.000000      0.000000           6
# 105          1.656566       4.848485      0.269360         297
# 106         14.000000      22.000000      0.000000           1
#
# [107 rows x 9 columns]

# %% [markdown]
# ## build grid and upload to plotly

# %%
years_from_col = set(round(dataset['PUBYEAR'],0))
years_ints = sorted(list(years_from_col))
years = [str(year) for year in years_ints]
#years.remove('2009')

# make list of keywords
countries = []
for country in dataset['COUNTRYCODE']:
    if country not in countries: 
        countries.append(country)
        
columns = []
# make grid
for year in years:
    for country in countries:
        dataset_by_year = dataset[dataset['PUBYEAR'] == int(year)]
        dataset_by_year_and_country= dataset_by_year[dataset_by_year['COUNTRYCODE'] == country]
        for col_name in dataset_by_year_and_country:
            # each column name is unique
            column_name = '{year}_{country}_{header}_grid'.format(
                year=year, country=country, header=col_name
            )
            a_column = Column(list(dataset_by_year_and_country[col_name]), column_name)
            columns.append(a_column)

# upload grid
grid = Grid(columns)
url = py.grid_ops.upload(grid, 'grid'+str(time.time()), auto_open=False)
url
# Out:
# 'https://plot.ly/~mathias.riechert/71/'

# %% [markdown]
# ## Build visualization and upload

# %%
CONSTz='NUM_PAPERS'



#make figure:
figure = {
    'data': [],
    'layout': {},
    'frames': [],
    'config': {'scrollzoom': True}
}

# fill in most of layout
figure['layout']['title'] = 'Paper with "big data" keywords per country'
figure['layout']['geo'] = {'showframe':False, 'showcoastlines':True, 'projection':{'type':'Mercator'}}
figure['layout']['hovermode'] = 'closest'
figure['layout']['margin'] = {'r': 250}
figure['layout']['slider'] = {
    'args': [
        'slider.value', {
            'duration': 700,
            'ease': 'cubic-in-out'
        }
    ],
    'initialValue': '2009',
    'plotlycommand': 'animate',
    'values': years,
    'visible': True
}

figure['layout']['updatemenus'] = [
    {
        'buttons': [
            {
                'args': [None, {'frame': {'duration': 500, 'redraw': True},
                         'fromcurrent': True, 'transition': {'duration': 300, 'easing': 'quadratic-in-out'}}],
                'label': 'Play',
                'method': 'animate'
            },
            {
                'args': [[None], {'frame': {'duration': 0, 'redraw': True}, 'mode': 'immediate',
                'transition': {'duration': 0}}],
                'label': 'Pause',
                'method': 'animate'
            }
        ],
        'direction': 'left',
        'pad': {'r': 10, 't': 87},
        'showactive': False,
        'type': 'buttons',
        'x': 0.1,
        'xanchor': 'right',
        'y': 0,
        'yanchor': 'top'
    }
]


sliders_dict = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20},
        'prefix': 'Year:',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300, 'easing': 'cubic-in-out'},
    'pad': {'b': 10, 't': 50},
    'len': 0.9,
    'x': 0.1,
    'y': 0,
    'steps': []
}

col_name_template = '{year}_{country}_{header}_grid'

year = 2009
for country in countries:
    data_dict = {
        'type':'choropleth',
        'locationsrc':grid.get_column_reference(col_name_template.format(
            year=year, country=country, header='COUNTRYCODE')),
        'zsrc':grid.get_column_reference(col_name_template.format(
            year=year, country=country, header=CONSTz)),
        'textsrc': grid.get_column_reference(col_name_template.format(
            year=year, country=country, header='COUNTRYCODE')),
        'colorscale':[[0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
            [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
        'autocolorscale':False,
        'reversescale':True,
        'marker': {
            'line':{
                'color': 'rgb(180,180,180)',
                'width':0.5           
            }},
            'colorbar':{
                'autotick':False,
                'title':'#paper'
            }
        }
    figure['data'].append(data_dict)

# %%
# check if there is meaningful content in data:
figure['data']
# Out:
# [{'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:e6a26b',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:e6a26b',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:4736e5'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:1e01ca',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:1e01ca',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:daae33'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:02b728',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:02b728',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:0eedc4'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:fbe8eb',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:fbe8eb',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:75c9cc'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:20715b',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:20715b',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:2e5c2c'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:da884b',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:da884b',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:6ebc57'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:31f75d',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:31f75d',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:2a0dc0'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:8046e4',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:8046e4',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:16a96b'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:155cb0',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:155cb0',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:9d1219'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:4f3002',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:4f3002',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:7d4721'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:4fd73e',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:4fd73e',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:255cd6'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:783a1b',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:783a1b',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:58dfd3'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:50146c',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:50146c',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:471803'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:a205d8',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:a205d8',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:03bea3'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:ee4847',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:ee4847',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:a92af5'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:563a65',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:563a65',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:6cd2c3'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:e7d94b',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:e7d94b',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:562ed1'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:daf30a',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:daf30a',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:a9dc63'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:72d37c',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:72d37c',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:e32d50'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:84cbd8',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:84cbd8',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:cd9e8b'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:f2c255',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:f2c255',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:1cf30d'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:82870b',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:82870b',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:41298c'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:0c6b1b',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:0c6b1b',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:68f45c'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:f22be7',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:f22be7',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:c0ad14'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:aed2bd',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:aed2bd',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:e8153b'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:ef117f',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:ef117f',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:38a419'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:a170f2',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:a170f2',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:e4c44a'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:ce315e',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:ce315e',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:801020'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:bc0cb6',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:bc0cb6',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:7f0307'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:f44368',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:f44368',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:5be77d'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:977b4f',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:977b4f',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:2759e7'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:a6c59f',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:a6c59f',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:37da96'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:95b670',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:95b670',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:5b482a'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:d46cda',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:d46cda',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:6cb884'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:78ec3c',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:78ec3c',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:de091f'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:2b631b',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:2b631b',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:c5d946'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:6d559d',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:6d559d',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:bfeab7'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:6554df',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:6554df',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:f1c94b'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:778fea',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:778fea',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:5c80d1'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:6fb578',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:6fb578',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:38de7d'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:92b923',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:92b923',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:ee57ed'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:15939a',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:15939a',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:e07ba7'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:e3c87f',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:e3c87f',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:e70010'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:4ad592',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:4ad592',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:3eec71'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:c68a23',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:c68a23',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:9359bc'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:fb2873',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:fb2873',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:c3d932'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:c9e5f2',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:c9e5f2',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:0cd4df'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:7d848f',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:7d848f',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:97e08c'},
#  {'autocolorscale': False,
#   'colorbar': {'autotick': False, 'title': '#paper'},
#   'colorscale': [[0, 'rgb(5, 10, 172)'],
#    [0.35, 'rgb(40, 60, 190)'],
#    [0.5, 'rgb(70, 100, 245)'],
#    [0.6, 'rgb(90, 120, 245)'],
#    [0.7, 'rgb(106, 137, 247)'],
#    [1, 'rgb(220, 220, 220)']],
#   'locationsrc': 'mathias.riechert:71:6e58e3',
#   'marker': {'line': {'color': 'rgb(180,180,180)', 'width': 0.5}},
#   'reversescale': True,
#   'textsrc': 'mathias.riechert:71:6e58e3',
#   'type': 'choropleth',
#   'zsrc': 'mathias.riechert:71:5b5d26'}]

# %%
#locationsrc, zrsc and textsrc seem to have correct values --> let's look at a sample:

col_name_template.format(
            year=year, country=country, header=CONSTz)
# Out:
# '2009_URY_NUM_PAPERS_grid'

# %%
#looks good, now check if the resulting id fits:
grid.get_column_reference(col_name_template.format(
            year=year, country=country, header=CONSTz))
# Out:
# 'mathias.riechert:71:5b5d26'

# %%
for year in years:
    frame = {'data': [], 'name': str(year)}
    for country in countries:
        data_dict = {
            'type':'choropleth',
            'locationsrc':grid.get_column_reference(col_name_template.format(
                year=year, country=country, header='COUNTRYCODE')),
            'zsrc':grid.get_column_reference(col_name_template.format(
                year=year, country=country, header=CONSTz)),
            'textsrc': grid.get_column_reference(col_name_template.format(
                year=year, country=country, header='COUNTRYCODE')),
            'colorscale':[[0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
            [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
            'autocolorscale':False,
            'reversescale':True,
            'marker': {
                'line':{
                    'color': 'rgb(180,180,180)',
                    'width':0.5           
                }},
                'colorbar':{
                    'autotick':False,
                    'title':'#paper'
                }
            }
        frame['data'].append(data_dict)

    figure['frames'].append(frame)
    slider_step = {'args': [
        [year],
        {'frame': {'duration': 300, 'redraw': True},
         'mode': 'immediate',
       'transition': {'duration': 300}}
     ],
     'label': year,
     'method': 'animate'}
    sliders_dict['steps'].append(slider_step)

figure['layout']['sliders'] = [sliders_dict]
py.icreate_animations(figure, 'BigDataPapersWorldMap'+str(time.time()))
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mathias.riechert/72.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# no fills, only the years. Maybe the colorscale has to be set differently?
#
# The map can be found here: https://plot.ly/~mathias.riechert/72
